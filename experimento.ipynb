# %% [markdown]
# # QLCM-Qiskit: Experimento con FakeLima
# Resultados reproducibles con ruido real de ibmq_lima
# Autora: Osmary Lisbeth Navarro Tovar

# %%
from logon import Logon
from coherencia import calcular_Hs
import numpy as np

# Logones de ejemplo
amor = Logon(0.9, 0.95, np.pi/4)
paz = Logon(0.85, 0.92, np.pi/5)
ruido = Logon(0.3, 0.2, np.pi)

print("H_s (amor-paz):", calcular_Hs(amor, paz))
print("H_s (amor-ruido):", calcular_Hs(amor, ruido))
